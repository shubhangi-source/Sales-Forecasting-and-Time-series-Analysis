# %%
import numpy as np
import pandas as pd

df=pd.read_csv("../data/train.csv")
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_5072\2246991938.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("../data/train.csv")

# %% [markdown]
# Convert Date to datetime

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %% [markdown]
# Check missing values

# %%
print(df.isnull().sum())
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %% [markdown]
#  Check duplicate rows

# %%
print(f"Duplicate rows: {df.duplicated().sum()}")
# Out:
# Duplicate rows: 0

# %% [markdown]
# Remove closed stores

# %%
df=df[df["Open"]==1]

# %% [markdown]
#  Sort by Date

# %%
df = df.sort_values(["Store", "Date"]).reset_index(drop=True)

# %% [markdown]
# Save processed dataset

# %%
df.to_csv("processed_sales_data.csv", index=False)

print("Processed dataset saved successfully!")
# Out:
# Processed dataset saved successfully!
