# %%
import pandas as pd
df=pd.read_csv("data/processed_sales_data.csv",parse_dates=["Date"])

# %%
df["Date"]=pd.to_datetime(df["Date"])
df["Year"]=df["Date"].dt.year
df["Month"]=df["Date"].dt.year
df["Day"]=df["Date"].dt.day
df["Week"]=df["Date"].dt.isocalendar().week.astype(int)
df["Quarter"]=df["Date"].dt.quarter
df["DayOfWeek"]=df["Date"].dt.day_of_week
df["IsWeekend"]=(df["DayOfWeek"]>=5).astype(int)

df["IsMonthStart"]=df["Date"].dt.is_month_start.astype(int)
df["IsMonthEnd"]=df["Date"].dt.is_month_end.astype(int)

# %% [markdown]
# # Encode Categorical Variable

# %%
df["StateHoliday"]=df["StateHoliday"].astype(str)
df=pd.get_dummies(df,columns=["StateHoliday"],drop_first=True)

# %% [markdown]
# # Lag Features

# %%
df["Lag_1"]=df["Sales"].shift(1)
df["Lag_7"]=df["Sales"].shift(7)
df["Lag_30"]=df["Sales"].shift(30)

# %% [markdown]
# # Rolling Features

# %%
df["RollingMean7"]=df["Sales"].rolling(7).mean()
df["RollingMean30"]=df["Sales"].rolling(30).mean()
df["RollingStd7"]=df["Sales"].rolling(7).std()
df["RollingStd30"]=df["Sales"].rolling(30).std()

# %% [markdown]
# # Expanding Mean

# %%
df["ExpandingMean"]=df["Sales"].expanding().mean()

# %% [markdown]
# # Remove NaN Values

# %%
df.dropna(inplace=True)

# %% [markdown]
# # Reset Index

# %%
df.reset_index(drop=True,inplace=True)

# %% [markdown]
# # Final Check

# %%
print(df.head())
df.columns
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo  SchoolHoliday  \
# 0     89          4 2015-07-31   7295        716     1      1              0
# 1     90          4 2015-07-31  11495       1295     1      1              1
# 2     91          4 2015-07-31   6164        554     1      1              1
# 3     92          4 2015-07-31   8227        701     1      1              1
# 4     93          4 2015-07-31   6548        715     1      1              1
#
#    Year  Month  ...  StateHoliday_b  StateHoliday_c    Lag_1    Lag_7  \
# 0  2015   2015  ...           False           False   7863.0  11492.0
# 1  2015   2015  ...           False           False   7295.0   3866.0
# 2  2015   2015  ...           False           False  11495.0  14949.0
# 3  2015   2015  ...           False           False   6164.0   7791.0
# 4  2015   2015  ...           False           False   8227.0   5572.0
#
#     Lag_30  RollingMean7  RollingMean30  RollingStd7  ExpandingMean  \
# 0   7148.0   7673.571429    8775.666667  3505.114542    8775.666667
# 1   9762.0   8763.428571    8833.433333  3304.193389    8863.387097
# 2   5572.0   7508.428571    8853.166667  1956.899065    8779.031250
# 3   7495.0   7570.714286    8877.566667  1974.253675    8762.303030
# 4  11525.0   7710.142857    8711.666667  1839.432379    8697.176471
#
#    RollingStd30
# 0   2712.936624
# 1   2752.820117
# 2   2730.667369
# 3   2721.367502
# 4   2706.070345
#
# [5 rows x 27 columns]
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'SchoolHoliday', 'Year', 'Month', 'Day', 'Week', 'Quarter', 'IsWeekend',
#        'IsMonthStart', 'IsMonthEnd', 'StateHoliday_a', 'StateHoliday_b',
#        'StateHoliday_c', 'Lag_1', 'Lag_7', 'Lag_30', 'RollingMean7',
#        'RollingMean30', 'RollingStd7', 'ExpandingMean', 'RollingStd30'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 844304 entries, 0 to 844303
# Data columns (total 27 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Store           844304 non-null  int64
#  1   DayOfWeek       844304 non-null  int32
#  2   Date            844304 non-null  datetime64[ns]
#  3   Sales           844304 non-null  int64
#  4   Customers       844304 non-null  int64
#  5   Open            844304 non-null  int64
#  6   Promo           844304 non-null  int64
#  7   SchoolHoliday   844304 non-null  int64
#  8   Year            844304 non-null  int32
#  9   Month           844304 non-null  int32
#  10  Day             844304 non-null  int32
#  11  Week            844304 non-null  int64
#  12  Quarter         844304 non-null  int32
#  13  IsWeekend       844304 non-null  int64
#  14  IsMonthStart    844304 non-null  int64
#  15  IsMonthEnd      844304 non-null  int64
#  16  StateHoliday_a  844304 non-null  bool
#  17  StateHoliday_b  844304 non-null  bool
#  18  StateHoliday_c  844304 non-null  bool
#  19  Lag_1           844304 non-null  float64
#  20  Lag_7           844304 non-null  float64
#  21  Lag_30          844304 non-null  float64
#  22  RollingMean7    844304 non-null  float64
#  23  RollingMean30   844304 non-null  float64
#  24  RollingStd7     844304 non-null  float64
#  25  ExpandingMean   844304 non-null  float64
#  26  RollingStd30    844304 non-null  float64
# dtypes: bool(3), datetime64[ns](1), float64(8), int32(5), int64(10)
# memory usage: 140.9 MB
# None

# %% [markdown]
# # Save feature-engineered dataset

# %%
df.to_csv("featured__new_sales_data.csv", index=False)

print("Feature-engineered dataset saved successfully!")
# Out:
# Feature-engineered dataset saved successfully!
