# %%
import numpy as np
import pandas as pd

df=pd.read_csv("data/train.csv")
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_21724\343547399.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("data/train.csv")

# %% [markdown]
# Convert Date to datetime

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %% [markdown]
# Check missing values

# %%
print(df.isnull().sum())
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %% [markdown]
#  Check duplicate rows

# %%
print(f"Duplicate rows: {df.duplicated().sum()}")
# Out:
# Duplicate rows: 0

# %% [markdown]
# Remove closed stores

# %%
df=df[df["Open"]==1]

# %% [markdown]
#  Sort by Date

# %%
df.sort_values("Date")
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 1017190   1097          2 2013-01-01   5961       1405     1      0
# 1016179     85          2 2013-01-01   4220        619     1      0
# 1016353    259          2 2013-01-01   6851       1444     1      0
# 1016356    262          2 2013-01-01  17267       2875     1      0
# 1016368    274          2 2013-01-01   3102        729     1      0
# ...        ...        ...        ...    ...        ...   ...    ...
# 744        745          5 2015-07-31   8363        746     1      1
# 745        746          5 2015-07-31   9082        638     1      1
# 746        747          5 2015-07-31  10708        826     1      1
# 740        741          5 2015-07-31  11253       1137     1      1
# 0            1          5 2015-07-31   5263        555     1      1
#
#         StateHoliday  SchoolHoliday
# 1017190            a              1
# 1016179            a              1
# 1016353            a              1
# 1016356            a              1
# 1016368            a              1
# ...              ...            ...
# 744                0              1
# 745                0              1
# 746                0              1
# 740                0              1
# 0                  0              1
#
# [844392 rows x 9 columns]

# %% [markdown]
# Save processed dataset

# %%
df.to_csv("processed_sales_data.csv", index=False)

print("Processed dataset saved successfully!")
# Out:
# Processed dataset saved successfully!
