# %%
# ================================
# Step 1: Load and Inspect Dataset
# ================================

# Import libraries
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv("train.csv")

# Random 5 rows
print("\nRandom Sample:")
print(df.sample(5))






# Unique values in important columns
print("\nUnique Stores:", df["Store"].nunique())
print("Unique Days:", df["DayOfWeek"].nunique())


# Check date range
print("\nDate Range:")
print("Start Date:", df["Date"].min())
print("End Date:", df["Date"].max())
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24984\917660804.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("train.csv")
# Random Sample:
#         Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 113264    650          2  2015-04-21   5518        579     1      0
# 804134   1005          4  2013-07-11   5185        876     1      0
# 177032    863          1  2015-02-23   6652        818     1      0
# 115584    740          7  2015-04-19      0          0     0      0
# 686874    820          4  2013-10-24  11696       1081     1      1
#
#        StateHoliday  SchoolHoliday
# 113264            0              0
# 804134            0              0
# 177032            0              0
# 115584            0              0
# 686874            0              0
#
# Unique Stores: 1115
# Unique Days: 7
#
# Date Range:
# Start Date: 2013-01-01
# End Date: 2015-07-31

# %%
print("\nDataset Shape:")
print(df.shape)

print("\nDataset Information:")
df.info()
# Out:
# Dataset Shape:
# (1017209, 9)
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %% [markdown]
# # Statistical summary

# %%
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday
# count  1.017209e+06   1.017209e+06
# mean   3.815145e-01   1.786467e-01
# std    4.857586e-01   3.830564e-01
# min    0.000000e+00   0.000000e+00
# 25%    0.000000e+00   0.000000e+00
# 50%    0.000000e+00   0.000000e+00
# ...

# %% [markdown]
# # Missing values

# %%
 
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %% [markdown]
# # Duplicate rows

# %%
print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# Duplicate Rows:
# 0

# %% [markdown]
# # Unique values in important columns

# %%
print("\nUnique Stores:", df["Store"].nunique())
print("Unique Days:", df["DayOfWeek"].nunique())
# Out:
# Unique Stores: 1115
# Unique Days: 7

# %% [markdown]
# # Check date range

# %%
print("\nDate Range:")
print("Start Date:", df["Date"].min())
print("End Date:", df["Date"].max())
# Out:
# Date Range:
# Start Date: 2013-01-01
# End Date: 2015-07-31
# dtype('O')

# %% [markdown]
# ## Observation
#
# - No missing values were found in the dataset.
# - No duplicate records were found.
# - Therefore, no data cleaning was required, and the dataset was ready for exploratory data analysis (EDA) and feature engineering.
